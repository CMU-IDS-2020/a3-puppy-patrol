# %%
import pandas as pd
import altair as alt

# %% [markdown]
# Assumes the data from [NYC Open Data](https://data.cityofnewyork.us/Social-Services/Rat-Sightings/3q43-55fe) on rat sightings is saved as `Rat_Sightings.csv` in the same directory. Removes rows that don't have any useful values.

# %%
useless_rows = ['Complaint Type',
                  'Descriptor',
                  'Vehicle Type',
                  'Taxi Company Borough',
                  'Taxi Pick Up Location',
                  'Bridge Highway Name',
                  'Bridge Highway Direction',
                  'Road Ramp',
                  'Bridge Highway Segment',
                  'Agency',
                  'Facility Type',
                  'Park Facility Name',
                  'Agency Name',
                  
                  # Not exactly useless, but low priority compared
                  # and we need to shave down MBs
                  'Intersection Street 1',
                  'Intersection Street 2',
                  'Cross Street 1',
                  'Cross Street 2',
                
                  # already covered by individual lat/lon categories
                  'Location' 
                  ]

# %%
df_raw = pd.read_csv("Rat_Sightings.csv")

# %%
list(map(lambda c: df_raw[c].unique(), useless_rows))
# Out:
# [array(['Rodent'], dtype=object),
#  array(['Rat Sighting'], dtype=object),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array(['DOHMH'], dtype=object),
#  array([nan]),
#  array(['Unspecified'], dtype=object),
#  array(['Department of Health and Mental Hygiene'], dtype=object),
#  array(['21 AVENUE', 'AMSTERDAM AVENUE', 'SOUTHERN BOULEVARD', ...,
#         'GOWANUS EXPRESSWAY EXIT 17 WB', 'PARK LANE SOUTH',
#         'HEENAN AVENUE'], dtype=object),
#  array(['DITMARS BOULEVARD', 'BROADWAY', 'BRUCKNER BOULEVARD BIKE PATH',
#         ..., 'PRINCETON AVENUE', 'HARMON STREET', 'CHITTENDEN AVENUE'],
#        dtype=object),
#  array(['21 AVENUE', 'AMSTERDAM AVENUE', 'SOUTHERN BOULEVARD', ...,
#         'JOURNEAY STREET', 'SCARBORO AVENUE', 'RUTHERFORD PLACE'],
#        dtype=object),
#  array(['DITMARS BOULEVARD', 'BROADWAY', 'BRUCKNER BOULEVARD BIKE PATH',
#         ..., 'HAMILTON TERRACE', 'MAJOR DEEGAN EP NB EN E 135 ST',
#         'COLD SPRING ROAD'], dtype=object),
#  array(['(40.77592413205042, -73.90892350916926)',
#         '(40.82684357808373, -73.94737911756701)',
#         '(40.81619760257876, -73.89599977428821)', ...,
#         '(40.8070145, -73.9510432)', '(40.7047239, -73.9262068)',
#         '(40.6177644, -73.9842052)'], dtype=object)]

# %%
df = df_raw.drop(useless_rows, axis=1)
df
# Out:
#         Unique Key            Created Date             Closed Date  \
# 0         47741820  09/30/2020 05:54:51 PM                     NaN
# 1         47740411  09/30/2020 08:18:28 PM                     NaN
# 2         47739788  09/30/2020 04:29:45 PM                     NaN
# 3         47738778  09/30/2020 11:13:17 AM                     NaN
# 4         47739099  09/30/2020 02:31:00 PM                     NaN
# ...            ...                     ...                     ...
# 153406    42039339  03/25/2019 12:00:00 AM  03/25/2019 12:00:00 AM
# 153407    42041693  03/24/2019 12:00:00 AM  03/24/2019 12:00:00 AM
# 153408    42041694  03/24/2019 12:00:00 AM  03/26/2019 12:00:00 AM
# 153409    42042459  03/24/2019 12:00:00 AM  03/24/2019 12:00:00 AM
# 153410    42051319  03/25/2019 06:02:46 AM  03/26/2019 12:00:00 AM
#
#                        Location Type  Incident Zip      Incident Address  \
# 0       3+ Family Mixed Use Building       11105.0       21-77 33 STREET
# 1            3+ Family Apt. Building       10031.0  517 WEST  147 STREET
# 2                Government Building       10459.0  1035 LONGWOOD AVENUE
# 3                Commercial Building       11211.0      496 GRAND STREET
# 4                1-2 Family Dwelling       11203.0      EAST   51 STREET
# ...                              ...           ...                   ...
# 153406       3+ Family Apt. Building       10014.0       47 PERRY STREET
# 153407       3+ Family Apt. Building       10009.0          153 AVENUE A
# 153408           Commercial Building       11204.0        6215 20 AVENUE
# 153409       3+ Family Apt. Building       10455.0      756 KELLY STREET
# 153410       3+ Family Apt. Building       10034.0        74 POST AVENUE
#
#              Street Name Address Type      City          Landmark  \
# 0              33 STREET          NaN   ASTORIA         33 STREET
# 1       WEST  147 STREET          NaN  NEW YORK  WEST  147 STREET
# 2        LONGWOOD AVENUE          NaN     BRONX   LONGWOOD AVENUE
# 3           GRAND STREET          NaN  BROOKLYN      GRAND STREET
# 4       EAST   51 STREET          NaN       NaN               NaN
# ...                  ...          ...       ...               ...
# 153406      PERRY STREET      ADDRESS  NEW YORK               NaN
# 153407          AVENUE A      LATLONG  NEW YORK               NaN
# 153408         20 AVENUE      LATLONG  BROOKLYN               NaN
# 153409      KELLY STREET      LATLONG     BRONX               NaN
# 153410       POST AVENUE      ADDRESS  NEW YORK               NaN
#
#              Status                Due Date Resolution Action Updated Date  \
# 0       In Progress                     NaN                            NaN
# 1       In Progress                     NaN                            NaN
# 2       In Progress                     NaN                            NaN
# 3       In Progress                     NaN                            NaN
# 4       In Progress                     NaN                            NaN
# ...             ...                     ...                            ...
# 153406       Closed  04/24/2019 12:18:05 AM         03/25/2019 12:00:00 AM
# 153407       Closed  04/23/2019 11:51:59 AM         03/24/2019 11:55:26 AM
# 153408       Closed  04/23/2019 08:38:47 PM         03/26/2019 12:00:00 AM
# 153409       Closed  04/23/2019 10:26:37 PM         03/24/2019 12:00:00 AM
# 153410       Closed  04/24/2019 06:00:38 AM         03/26/2019 12:00:00 AM
#
#               Community Board    Borough  X Coordinate (State Plane)  \
# 0                   01 QUEENS     QUEENS                   1009475.0
# 1                09 MANHATTAN  MANHATTAN                    998813.0
# 2                    02 BRONX      BRONX                   1013037.0
# 3                 01 BROOKLYN   BROOKLYN                    997740.0
# 4                 17 BROOKLYN   BROOKLYN                   1003582.0
# ...                       ...        ...                         ...
# 153406           02 MANHATTAN  MANHATTAN                    983421.0
# 153407  Unspecified MANHATTAN  MANHATTAN                    989045.0
# 153408   Unspecified BROOKLYN   BROOKLYN                    988635.0
# 153409      Unspecified BRONX      BRONX                   1012293.0
# 153410           12 MANHATTAN  MANHATTAN                   1005773.0
#
#         Y Coordinate (State Plane) Park Borough   Latitude  Longitude
# 0                         221980.0       QUEENS  40.775924 -73.908924
# 1                         240523.0    MANHATTAN  40.826844 -73.947379
# 2                         236657.0        BRONX  40.816198 -73.896000
# 3                         198290.0     BROOKLYN  40.710927 -73.951341
# 4                         179979.0     BROOKLYN  40.660656 -73.930321
# ...                            ...          ...        ...        ...
# 153406                    207274.0    MANHATTAN  40.735596 -74.002991
# 153407                    204411.0    MANHATTAN  40.727739 -73.982700
# 153408                    164344.0     BROOKLYN  40.617764 -73.984205
# 153409                    237015.0        BRONX  40.817185 -73.898686
# 153410                    253984.0    MANHATTAN  40.863776 -73.922187
#
# [153411 rows x 20 columns]

# %%
list(df.columns)
# Out:
# ['Unique Key',
#  'Created Date',
#  'Closed Date',
#  'Location Type',
#  'Incident Zip',
#  'Incident Address',
#  'Street Name',
#  'Address Type',
#  'City',
#  'Landmark',
#  'Status',
#  'Due Date',
#  'Resolution Action Updated Date',
#  'Community Board',
#  'Borough',
#  'X Coordinate (State Plane)',
#  'Y Coordinate (State Plane)',
#  'Park Borough',
#  'Latitude',
#  'Longitude']

# %%
#df['Intersection Street 2'].unique()

# %%
df.to_csv('rats.csv')
